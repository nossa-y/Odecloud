# %%
# FOCUSING ON THE FIRST 6 COLUMNS 
# 1st method : putting them on a much higher scale (checker evolution)
# feature engineering

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/time-track/time_track.csv

# %%
data = pd.read_csv("/kaggle/input/time-track/time_track.csv")
data.head()
# Out:
#                                   #  Sales activities / Biz Dev  \
# 0  x65yz81z61pa0busf3x65yc4fs94brkt                         2.0
# 1  z9rnp5qq6tlbrh2oyz9rn9rxfpup1ntj                         3.0
# 2  k4kpfxpra8ezq749k4kppw6bntki2nns                         2.0
# 3  904gynnnwmfugj904gpj7xg18tftb7l8                         5.0
# 4  iw5awzvddi1pgk04liw5awqq0hdz6m9n                         5.0
#
#    NetSuite Solution Architect  NetSuite configuration / customization  \
# 0                          5.0                                     4.0
# 1                          4.0                                     4.0
# 2                          4.0                                     3.0
# 3                          3.0                                     4.0
# 4                          3.0                                     4.0
#
#    Technical/ NetSuite development / Systems Integration  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                5.0
# 4                                                4.0
#
#    How would you rate your experience with *SuiteScript 1.0*?  \
# 0                                                NaN
# 1                                                2.0
# 2                                                1.0
# 3                                                3.0
# 4                                                6.0
#
#    How would you rate your experience with *SuiteScript 2.0*?  \
# 0                                                NaN
# 1                                                2.0
# 2                                                1.0
# 3                                                9.0
# 4                                                7.0
#
#    How would you rate your experience with *Suitelets*?  \
# 0                                                NaN
# 1                                                2.0
# 2                                                2.0
# 3                                                8.0
# 4                                                8.0
#
#    How would you rate your experience with *SuiteCloud Development Framework (SDF)*?  \
# 0                                                NaN
# 1                                                3.0
# 2                                                2.0
# 3                                                9.0
# 4                                                9.0
#
#    How would you rate your experience with *ECMAScript*?  ...  \
# 0                                                NaN      ...
# 1                                                2.0      ...
# 2                                                2.0      ...
# 3                                                3.0      ...
# 4                                                6.0      ...
#
#                  What comes first?  \
# 0  Maximum cash (at least for now)
# 1  Maximum cash (at least for now)
# 2  Maximum cash (at least for now)
# 3                Work life balance
# 4  Maximum cash (at least for now)
#
#    Finally, would you be interested in freelance opportunities with OdeCloud?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Any preferred industry you'd like to work in?  \
# 0                                  Manufacturing
# 1                        Manufacturing/Wholesale
# 2                                  Manufacturing
# 3                                            NaN
# 4                                            sdf
#
#      Any suggestions to improve this questionnaire?   \
# 0  1. h. How would you rate your experience with ...
# 1  Ask less technical questions. There are a ton ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    We would love to follow up with you. Please leave us your email.  \
# 0                       andrew.altringer@outlook.com
# 1                       andrew.altringer@outlook.com
# 2                       andrew.altringer@outlook.com
# 3                           wilson.system1@gmail.com
# 4                              vanielle@odecloud.com
#
#    Please enter your first and last name.     Start Date (UTC)  \
# 0                        Andrew Altringer  2023-02-07 04:46:07
# 1                        Andrew Altringer  2023-02-04 05:16:17
# 2                        Andrew Altringer  2023-01-13 04:07:50
# 3                                  Wilson  2022-11-21 23:28:54
# 4                            Vanielle Lee  2022-11-17 02:52:03
#
#      Submit Date (UTC)  Network ID  Tags
# 0  2023-02-07 05:11:43  0c12fa5b48   NaN
# 1  2023-02-04 06:08:28  0c12fa5b48   NaN
# 2  2023-01-13 04:14:22  0c12fa5b48   NaN
# 3  2022-11-21 23:35:36  e21e2855a2   NaN
# 4  2022-11-17 03:36:06  2d134852ae   NaN
#
# [5 rows x 103 columns]

# %%
#average number of missing value in columns
L = []
for col in data.columns:
    L.append(data[col].isnull().sum())
n = len(L)
s=0
for i in L:
    s += i
print(s/n)
# Out:
# 30.145631067961165

# %%
cols_with_lot_missing = [ col for col in data.columns
                        if (data[col].isnull().sum() > 30)]

len(cols_with_lot_missing) #52 in 103 cols
# Out:
# 52

# %%
#average number of question people don't answer
L = []
for row in data.index:
    L.append(data.iloc[row, :].isnull().sum())
n = len(L)
s=0
for i in L:
    s += i
print(s/n) #35 in 88
# Out:
# 35.28409090909091

# %%
rows_with_lot_missing = [row for row in data.index
                        if data.iloc[row, :].isnull().sum() > 35]

len(rows_with_lot_missing) #in 88 rows
# Out:
# 36

# %%
data2 = data.drop(cols_with_lot_missing, axis = 1)
data3 = data2.drop(rows_with_lot_missing, axis = 0)

print(data3.shape)
#data3
# Out:
# (52, 51)

# %%
data3.head()
# Out:
#                                   #  Sales activities / Biz Dev  \
# 0  x65yz81z61pa0busf3x65yc4fs94brkt                         2.0
# 1  z9rnp5qq6tlbrh2oyz9rn9rxfpup1ntj                         3.0
# 2  k4kpfxpra8ezq749k4kppw6bntki2nns                         2.0
# 4  iw5awzvddi1pgk04liw5awqq0hdz6m9n                         5.0
# 6  uoyuppi0nnx7xjeuoyupptlted1b7nvp                         5.0
#
#    NetSuite Solution Architect  NetSuite configuration / customization  \
# 0                          5.0                                     4.0
# 1                          4.0                                     4.0
# 2                          4.0                                     3.0
# 4                          3.0                                     4.0
# 6                          3.0                                     4.0
#
#    Technical/ NetSuite development / Systems Integration  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 4                                                4.0
# 6                                                1.0
#
#    NetSuite Implementation projects  \
# 0                               2.0
# 1                               4.0
# 2                               2.0
# 4                               4.0
# 6                               5.0
#
#    Ongoing long-term (post go-live) NetSuite optimization projects  \
# 0                                                5.0
# 1                                                4.0
# 2                                                5.0
# 4                                                5.0
# 6                                                5.0
#
#    Ongoing long-term NetSuite admin and end-user support  \
# 0                                                4.0
# 1                                                5.0
# 2                                                5.0
# 4                                                3.0
# 6                                                5.0
#
#    A NetSuite optimization project occasionally  \
# 0                                           4.0
# 1                                           3.0
# 2                                           2.0
# 4                                           3.0
# 6                                           5.0
#
#    Are you interested in writing and monetizing NetSuite articles and tutorials?   \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 4                                                0.0
# 6                                                1.0
#
#    ... Right now, do you have bandwidth for more clients?  \
# 0  ...                                                1.0
# 1  ...                                                1.0
# 2  ...                                                0.0
# 4  ...                                                1.0
# 6  ...                                                1.0
#
#   How is work life balance these days?                What comes first?  \
# 0                                  4.0  Maximum cash (at least for now)
# 1                                  4.0  Maximum cash (at least for now)
# 2                                  2.0  Maximum cash (at least for now)
# 4                                  4.0  Maximum cash (at least for now)
# 6                                  4.0  Maximum cash (at least for now)
#
#    Finally, would you be interested in freelance opportunities with OdeCloud?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 4                                                1.0
# 6                                                1.0
#
#   Any preferred industry you'd like to work in?  \
# 0                                 Manufacturing
# 1                       Manufacturing/Wholesale
# 2                                 Manufacturing
# 4                                           sdf
# 6                                            No
#
#    We would love to follow up with you. Please leave us your email.  \
# 0                       andrew.altringer@outlook.com
# 1                       andrew.altringer@outlook.com
# 2                       andrew.altringer@outlook.com
# 4                              vanielle@odecloud.com
# 6                             Nada.iraqi99@gmail.com
#
#    Please enter your first and last name.     Start Date (UTC)  \
# 0                        Andrew Altringer  2023-02-07 04:46:07
# 1                        Andrew Altringer  2023-02-04 05:16:17
# 2                        Andrew Altringer  2023-01-13 04:07:50
# 4                            Vanielle Lee  2022-11-17 02:52:03
# 6                              Nada Ahmed  2022-09-28 16:10:23
#
#      Submit Date (UTC)  Network ID
# 0  2023-02-07 05:11:43  0c12fa5b48
# 1  2023-02-04 06:08:28  0c12fa5b48
# 2  2023-01-13 04:14:22  0c12fa5b48
# 4  2022-11-17 03:36:06  2d134852ae
# 6  2022-09-28 16:20:00  b64912cf75
#
# [5 rows x 51 columns]

# %%
#distinction num varialble and cat variables
num_col = [col for col in data3.columns
          if data3[col].dtype in ['int64', 'float64']]
len(num_col)
# Out:
# 38

# %%
object_col = [col for col in data3.columns
             if data3[col].dtype == 'object']
len(object_col)
# Out:
# 13

# %%
#average unique value for each col in object_col
n = len(object_col)
s = 0

for col in object_col[1:]:
    s += data3[col].unique().shape[0]
    
print(s/n)
# Out:
# 25.846153846153847

# %%
#cleaning data I'm not going to work with

#1 droping col because of their unicity

cat_col_to_remove = [col for col in object_col
          if data3[col].unique().shape[0] > 25] #10 is advised but with 10 or 25 we get the same result

cat_col_to_remove
# Out:
# ['#',
#  "Lastly, would you mind sharing the name of a few companies you've worked with as a NetSuite professional?",
#  "Any preferred industry you'd like to work in?",
#  'We would love to follow up with you. Please leave us your email.',
#  'Please enter your first and last name.',
#  'Start Date (UTC)',
#  'Submit Date (UTC)',
#  'Network ID']

# %%
data4 = data3.drop(cat_col_to_remove, axis = 1)
#data4

# %%
#2 droping row because of their missing value in the col we want to predict

data4 = data4.dropna(subset = ['How many clients do you usually (would you) take on at a time?'])
data4 = data4.reset_index(drop = True)
data4.shape # (40, 45) c'etait (40, 43) avant
# Out:
# (40, 43)

# %%
# method : simple imputer for numerical values and hot encoder for categorical ones

# %%
#distinction num varialble and cat variables
num_cole = [col for col in data5.columns
          if data5[col].dtype in ['int64', 'float64']]
len(num_col)
data4.head()
# Out:
#    Sales activities / Biz Dev  NetSuite Solution Architect  \
# 0                         2.0                          5.0
# 1                         3.0                          4.0
# 2                         2.0                          4.0
# 3                         5.0                          3.0
# 4                         5.0                          3.0
#
#    NetSuite configuration / customization  \
# 0                                     4.0
# 1                                     4.0
# 2                                     3.0
# 3                                     4.0
# 4                                     5.0
#
#    Technical/ NetSuite development / Systems Integration  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                1.0
# 4                                                1.0
#
#    NetSuite Implementation projects  \
# 0                               2.0
# 1                               4.0
# 2                               2.0
# 3                               5.0
# 4                               5.0
#
#    Ongoing long-term (post go-live) NetSuite optimization projects  \
# 0                                                5.0
# 1                                                4.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    Ongoing long-term NetSuite admin and end-user support  \
# 0                                                4.0
# 1                                                5.0
# 2                                                5.0
# 3                                                5.0
# 4                                                5.0
#
#    A NetSuite optimization project occasionally  \
# 0                                           4.0
# 1                                           3.0
# 2                                           2.0
# 3                                           5.0
# 4                                           5.0
#
#    Are you interested in writing and monetizing NetSuite articles and tutorials?   \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#   How do you prefer to get paid for your NetSuite service?  ...  \
# 0                                             Hourly        ...
# 1                            Fixed-price per project        ...
# 2                            Fixed-price per project        ...
# 3                                             Hourly        ...
# 4                                             Hourly        ...
#
#   How would you rate yourself in the* Software* vertical of NetSuite?  \
# 0                                                6.0
# 1                                                7.0
# 2                                                7.0
# 3                                                5.0
# 4                                                4.0
#
#   How would you rate yourself in the* Professional Services* vertical of NetSuite?  \
# 0                                                4.0
# 1                                                2.0
# 2                                                2.0
# 3                                                6.0
# 4                                                7.0
#
#    How would you rate yourself in the* Ecommerce* vertical of NetSuite?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                6.0
# 4                                                8.0
#
#   How would you rate yourself in the* Health and Beauty* vertical of NetSuite?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                2.0
# 3                                                6.0
# 4                                                9.0
#
#    How would you rate yourself in the* Financial Services* vertical of NetSuite?  \
# 0                                                5.0
# 1                                                3.0
# 2                                                3.0
# 3                                                8.0
# 4                                                8.0
#
#    How would you rate yourself in the* Media and Publishing* vertical of NetSuite?  \
# 0                                                3.0
# 1                                                2.0
# 2                                                2.0
# 3                                                6.0
# 4                                                8.0
#
#    Right now, do you have bandwidth for more clients?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# 3                                                1.0
# 4                                                1.0
#
#    How is work life balance these days?                What comes first?  \
# 0                                   4.0  Maximum cash (at least for now)
# 1                                   4.0  Maximum cash (at least for now)
# 2                                   2.0  Maximum cash (at least for now)
# 3                                   4.0  Maximum cash (at least for now)
# 4                                   4.0  Maximum cash (at least for now)
#
#    Finally, would you be interested in freelance opportunities with OdeCloud?
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
# [5 rows x 43 columns]

# %%
#distinction num varialble and cat variables removing the col we want to predict
object_cole = [col for col in data5.columns
          if ((data5[col].dtype == 'object') & (col != ('How many clients do you usually (would you) take on at a time?'))) ]
len(object_cole)
# Out:
# 4

# %%
for colname in X.select_dtypes('object'):
    X[colname], _ = X[colname].factorize()
X.head()
# Out:
#    Sales activities / Biz Dev  NetSuite Solution Architect  \
# 0                         2.0                          5.0
# 1                         3.0                          4.0
# 2                         2.0                          4.0
# 6                         5.0                          3.0
# 7                         5.0                          3.0
#
#    NetSuite configuration / customization  \
# 0                                     4.0
# 1                                     4.0
# 2                                     3.0
# 6                                     4.0
# 7                                     5.0
#
#    Technical/ NetSuite development / Systems Integration  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 6                                                1.0
# 7                                                1.0
#
#    NetSuite Implementation projects  \
# 0                               2.0
# 1                               4.0
# 2                               2.0
# 6                               5.0
# 7                               5.0
#
#    Ongoing long-term (post go-live) NetSuite optimization projects  \
# 0                                                5.0
# 1                                                4.0
# 2                                                5.0
# 6                                                5.0
# 7                                                5.0
#
#    Ongoing long-term NetSuite admin and end-user support  \
# 0                                                4.0
# 1                                                5.0
# 2                                                5.0
# 6                                                5.0
# 7                                                5.0
#
#    A NetSuite optimization project occasionally  \
# 0                                           4.0
# 1                                           3.0
# 2                                           2.0
# 6                                           5.0
# 7                                           5.0
#
#    Are you interested in writing and monetizing NetSuite articles and tutorials?   \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 6                                                1.0
# 7                                                1.0
#
#    How do you prefer to get paid for your NetSuite service?  ...  \
# 0                                                  0         ...
# 1                                                  1         ...
# 2                                                  1         ...
# 6                                                  0         ...
# 7                                                  0         ...
#
#    How would you rate yourself in the* Software* vertical of NetSuite?  \
# 0                                                6.0
# 1                                                7.0
# 2                                                7.0
# 6                                                5.0
# 7                                                4.0
#
#    How would you rate yourself in the* Professional Services* vertical of NetSuite?  \
# 0                                                4.0
# 1                                                2.0
# 2                                                2.0
# 6                                                6.0
# 7                                                7.0
#
#    How would you rate yourself in the* Ecommerce* vertical of NetSuite?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 6                                                6.0
# 7                                                8.0
#
#    How would you rate yourself in the* Health and Beauty* vertical of NetSuite?  \
# 0                                                2.0
# 1                                                2.0
# 2                                                2.0
# 6                                                6.0
# 7                                                9.0
#
#    How would you rate yourself in the* Financial Services* vertical of NetSuite?  \
# 0                                                5.0
# 1                                                3.0
# 2                                                3.0
# 6                                                8.0
# 7                                                8.0
#
#    How would you rate yourself in the* Media and Publishing* vertical of NetSuite?  \
# 0                                                3.0
# 1                                                2.0
# 2                                                2.0
# 6                                                6.0
# 7                                                8.0
#
#    Right now, do you have bandwidth for more clients?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                0.0
# 6                                                1.0
# 7                                                1.0
#
#    How is work life balance these days?  What comes first?  \
# 0                                   4.0                  0
# 1                                   4.0                  0
# 2                                   2.0                  0
# 6                                   4.0                  0
# 7                                   4.0                  0
#
#    Finally, would you be interested in freelance opportunities with OdeCloud?
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 6                                                1.0
# 7                                                1.0
#
# [5 rows x 42 columns]

# %%
from sklearn.feature_selection import mutual_info_classif

def make_mi_scores(X, y, discrete_features = True):
    mi_scores = mutual_info_classif(X, y, discrete_features = True)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y)
mi_score.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 9
#       6     mi_scores = mi_scores.sort_values(ascending=False)
#       7     return mi_scores
# ----> 9 mi_scores = make_mi_scores(X, y)
#      10 mi_score.head()
#
# Cell In[58], line 4, in make_mi_scores(X, y, discrete_features)
#       3 def make_mi_scores(X, y, discrete_features = True):
# ----> 4     mi_scores = mutual_info_classif(X, y, discrete_features = True)
#       5     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#       6     mi_scores = mi_scores.sort_values(ascending=False)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/feature_selection/_mutual_info.py:467, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state)
#     391 def mutual_info_classif(
#     392     X, y, *, discrete_features="auto", n_neighbors=3, copy=True, random_state=None
#     393 ):
#     394     """Estimate mutual information for a discrete target variable.
#     395
#     396     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     465            of a Random Vector:, Probl. Peredachi Inf., 23:2 (1987), 9-16
#     466     """
# --> 467     check_classification_targets(y)
#     468     return _estimate_mi(X, y, discrete_features, True, n_neighbors, copy, random_state)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'unknown'

# %%
#creation du tableau de mutuele info
#X_m X mutualisé
# puis my_pipeline.fit()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

X = data5.drop(['How many clients do you usually (would you) take on at a time?'], axis = 1)
y_bis = data5['How many clients do you usually (would you) take on at a time?']

# I am taking the average number given ( 2 or 3 become 2.5)
y = y_bis.copy()

for i in y.index:
    if len(y[i])>2:
        #print(len(y[i])+y[i][0])
        y[i] = (float(y[i][0])+float(y[i][len(y[i])-1]))/2
    else:
        y[i] = float(y[i][0])

X_train, X_val, y_train, y_val = train_test_split(X, y)
#X.iloc[13,:]
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#use of pipelines
# 1 defining preprocessing steps

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

#preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy = 'constant', fill_value = 0)

#preprocessing for categorical data
categorical_transformer = Pipeline( steps = [
    ('imputer', SimpleImputer(strategy = 'constant', fill_value = '0')),
    ('encoder', OneHotEncoder(handle_unknown = 'ignore'))
])

#gathering num and cat col by the preprocess
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, num_cole),
        ('cat', categorical_transformer, object_cole)
    ])

# %%
# 2 define a model

from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 500, random_state = 1)

# 3 creating and evaluating pipelines

from sklearn.metrics import mean_absolute_error

#gathering preprocessing and model code in a pipeline

my_pipeline = Pipeline( steps = [('preprocessor', preprocessor),
                                ('model', model)
                                ])

my_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'),
#                                                   ['Sales activities / Biz Dev',
#                                                    'NetSuite Solution '
#                                                    'Architect',
#                                                    'NetSuite configuration / '
#                                                    'customization',
#                                                    'Technical/ NetSuite '
#                                                    'development / Systems '
#                                                    'Integration',
#                                                    'NetSuite Implementation '
#                                                    'projects',
#                                                    'Ongoing long-term (post '
#                                                    'go-live) NetSuite '
#                                                    'opt...
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='0',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['How do you prefer to get '
#                                                    'paid for your NetSuite '
#                                                    'service?',
#                                                    'What is your favorite type '
#                                                    'of engagement?',
#                                                    'How many implementation '
#                                                    'projects have you been '
#                                                    'part of?',
#                                                    'What comes first?'])])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=500, random_state=1))])

# %%
#let's check the accuracy with cross validation :

from sklearn.model_selection import cross_val_score

scores = -1 * cross_val_score(my_pipeline, X, y,
                              cv = 5,
                              scoring = 'neg_mean_absolute_error')
scores.mean()
# Out:
# 0.957075

# %%
#un exemple

preds_test = my_pipeline.predict(X_val.iloc[:3, :]) # pas mal

for i in range (len(preds_test)):
    preds_test[i] = round(preds_test[i])


print(preds_test)
print(list(y_val)[:3])

mean_absolute_error(preds_test, y_val[:3])
# Out:
# [3. 3. 3.]
# [2.5, 4.5, 2.5]
# 0.8333333333333334

# %%
# mean accuracy for all consultants

preds = my_pipeline.predict(X_val)

#for i in range (len(preds)):
#   preds[i] = round(preds[i])

#print(preds)

mean_absolute_error(preds, y_val)
# Out:
# 0.8523

# %%
#let's check the accuracy with cross validation :

from sklearn.model_selection import cross_val_score

scores = -1 * cross_val_score(pipeline, X, y,
                              cv = 5,
                              scoring = 'neg_mean_absolute_error')
scores.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       1 #let's check the accuracy with cross validation :
#       3 from sklearn.model_selection import cross_val_score
# ----> 5 scores = -1 * cross_val_score(pipeline, X, y,
#       6                               cv = 5,
#       7                               scoring = 'neg_mean_absolute_error')
#       8 scores.mean()
#
# NameError: name 'pipeline' is not defined

# %%
#un exemple

preds_test = pipeline.predict(X_val.iloc[:2, :]) # pas mal

for i in range (len(preds_test)):
    preds_test[i] = round(preds_test[i])


print(preds_test)
print(list(y_val)[:2])

mean_absolute_error(preds_test, y_val[:2])
